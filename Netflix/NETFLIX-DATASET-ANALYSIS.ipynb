# %% [markdown]
# # <font color="#cc0000"><h3 align="center">EDA ON NETFLIX</h3></font>

# %% [markdown]
# <h1 align='center'>Dataset Description</h1>

# %% [markdown]
# <h3><b>Netflix - TV Shows and Movies</b></h3>
# <p>This data set was created to list all shows available on Netflix streaming, and analyze the data to find interesting facts. This data was acquired in July 2022 containing data available in the United States.</p>

# %% [markdown]
# <h3><b>Content</b></h3>
# <p>This dataset has two files containing the titles (titles.csv) and the cast (credits.csv) for the title.</p>
# <p>This dataset contains <b>+5k</b> unique <b>titles on Netflix</b> with 15 columns containing their information, including:</p>
# <p>‣ id: The title ID on JustWatch.<br>‣ title: The name of the title.<br>‣ show_type: TV show or movie.<br>‣ description: A brief description.<br>‣ release_year: The release year.<br>‣ age_certification: The age certification.<br>‣ runtime: The length of the episode (SHOW) or movie.<br>‣ genres: A list of genres.<br>‣ production_countries: A list of countries that produced the title.<br>‣ seasons: Number of seasons if it's a SHOW.<br>‣ imdb_id: The title ID on IMDB.<br>‣ imdb_score: Score on IMDB.<br>‣ imdb_votes: Votes on IMDB.<br>‣ tmdb_popularity: Popularity on TMDB.<br>‣ tmdb_score: Score on TMDB.</p>
# <p>And over +77k credits of actors and directors on Netflix titles with 5 columns containing their information, including:</p>
# <p>‣ person_ID: The person ID on JustWatch.<br>‣ id: The title ID on JustWatch.<br>‣ character_name: The character name.<br>‣ role: ACTOR or DIRECTOR.</p>

# %% [markdown]
# <h3>Import Library</h3>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h3>Import Dataset</h3>

# %%
df_title=pd.read_csv('titles.csv')
df_credit=pd.read_csv('credits.csv')

# %% [markdown]
# <h3>First DataFrame</h3>

# %%
df_title.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# ...

# %%
df_title.shape
# Out:
# (5850, 15)

# %% [markdown]
# <h3>Second DataFrame</h3>

# %%
df_credit.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
df_credit.shape
# Out:
# (77801, 5)

# %% [markdown]
# <h3>Data Cleaning On Title DataFrame</h3>

# %%
df_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# ...

# %%
df_title.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %% [markdown]
# <h3>Drop Some Column From Title DataFrame</h3>

# %%
df_title.drop(['age_certification','imdb_id','description'],axis=1,inplace=True)

# %% [markdown]
# <h3>Counting Of Null Value In Each Column</h3>

# %%
df_title.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# release_year               0
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %%
df_title[df_title['title'].isnull()]
# Out:
#              id title   type  release_year  runtime genres  \
# 1704  tm1063792   NaN  MOVIE          2015       11     []
#
#      production_countries  seasons  imdb_score  imdb_votes  tmdb_popularity  \
# 1704                   []      NaN         NaN         NaN              NaN
#
#       tmdb_score
# 1704         NaN

# %%
df_title.drop(1704,axis=0,inplace=True)

# %%
df_title.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# release_year               0
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3743
# imdb_score               481
# imdb_votes               497
# tmdb_popularity           90
# tmdb_score               310
# dtype: int64

# %%
df_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5849 entries, 0 to 5849
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5849 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5849 non-null   object
#  3   release_year          5849 non-null   int64
#  4   runtime               5849 non-null   int64
#  5   genres                5849 non-null   object
#  6   production_countries  5849 non-null   object
#  7   seasons               2106 non-null   float64
#  8   imdb_score            5368 non-null   float64
#  9   imdb_votes            5352 non-null   float64
#  10  tmdb_popularity       5759 non-null   float64
#  11  tmdb_score            5539 non-null   float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 594.0+ KB

# %%
df_title[df_title['seasons'].isnull()]
# Out:
#              id                                      title   type  \
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# 6       tm70993                              Life of Brian  MOVIE
# ...         ...                                        ...    ...
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#       release_year  runtime                                       genres  \
# 1             1976      114                           ['drama', 'crime']
# ...

# %%
df_title['seasons'].unique()
# Out:
# array([ 1., nan,  4.,  9., 24.,  5., 39., 10., 13., 42., 25., 21., 37.,
#         8., 29.,  7., 11., 14., 12.,  6., 32., 15., 19.,  2., 20.,  3.,
#        16.])

# %%
df_title['seasons'].fillna(1,inplace=True)

# %%
df_title.isnull().sum()
# Out:
# id                        0
# title                     0
# type                      0
# release_year              0
# runtime                   0
# genres                    0
# production_countries      0
# seasons                   0
# imdb_score              481
# imdb_votes              497
# tmdb_popularity          90
# tmdb_score              310
# dtype: int64

# %%
df_title['release_year'].unique()
# Out:
# array([1945, 1976, 1972, 1975, 1967, 1969, 1979, 1971, 1980, 1961, 1966,
#        1954, 1958, 1977, 1963, 1956, 1960, 1973, 1974, 1959, 1978, 1989,
#        1990, 1987, 1984, 1983, 1982, 1986, 1981, 1988, 1985, 2000, 1996,
#        1997, 1995, 1994, 1999, 1998, 1993, 1992, 1991, 2008, 2002, 2010,
#        2005, 2007, 2004, 2006, 2009, 2003, 2001, 2011, 2012, 2013, 2014,
#        2015, 2016, 2018, 2017, 2019, 2020, 2022, 2021], dtype=int64)

# %%
g=df_title.groupby("release_year")

# %%
g.mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19908\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#                  runtime   seasons  imdb_score    imdb_votes  tmdb_popularity  \
# release_year
# 1945           51.000000  1.000000         NaN           NaN         0.600000
# 1954          107.500000  1.000000    7.450000  21853.500000         5.549500
# 1956          120.000000  1.000000    6.700000    610.000000         0.849000
# 1958           77.000000  1.000000    7.500000   4471.000000         5.546000
# 1959          142.000000  1.000000    6.600000     78.000000         0.840000
# ...                  ...       ...         ...           ...              ...
# 2018           73.839586  1.344114    6.502186   9951.898907        12.288223
# ...

# %%
df_title = df_title.fillna(df_title.groupby('release_year').transform("mean"))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19908\2111691995.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_title = df_title.fillna(df_title.groupby('release_year').transform("mean"))

# %%
df_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5849 entries, 0 to 5849
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5849 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5849 non-null   object
#  3   release_year          5849 non-null   int64
#  4   runtime               5849 non-null   int64
#  5   genres                5849 non-null   object
#  6   production_countries  5849 non-null   object
#  7   seasons               5849 non-null   float64
#  8   imdb_score            5848 non-null   float64
#  9   imdb_votes            5848 non-null   float64
#  10  tmdb_popularity       5849 non-null   float64
#  11  tmdb_score            5848 non-null   float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 594.0+ KB

# %%
df_title.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# release_year            0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_score              1
# imdb_votes              1
# tmdb_popularity         0
# tmdb_score              1
# dtype: int64

# %%
df_title[df_title['imdb_score'].isnull()]
# Out:
#          id                                title  type  release_year  runtime  \
# 0  ts300399  Five Came Back: The Reference Films  SHOW          1945       51
#
#               genres production_countries  seasons  imdb_score  imdb_votes  \
# 0  ['documentation']               ['US']      1.0         NaN         NaN
#
#    tmdb_popularity  tmdb_score
# 0              0.6         NaN

# %%
df_title['imdb_score'].fillna(df_title['imdb_score'].mean(),inplace=True)

# %%
df_title['imdb_votes'].fillna(df_title['imdb_votes'].mean(),inplace=True)

# %%
df_title['tmdb_score'].fillna(df_title['tmdb_score'].mean(),inplace=True)

# %%
df_title.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# release_year            0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %%
df_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5849 entries, 0 to 5849
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5849 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5849 non-null   object
#  3   release_year          5849 non-null   int64
#  4   runtime               5849 non-null   int64
#  5   genres                5849 non-null   object
#  6   production_countries  5849 non-null   object
#  7   seasons               5849 non-null   float64
#  8   imdb_score            5849 non-null   float64
#  9   imdb_votes            5849 non-null   float64
#  10  tmdb_popularity       5849 non-null   float64
#  11  tmdb_score            5849 non-null   float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 594.0+ KB

# %% [markdown]
# <h3>Data Cleaning On Credit DataFrame</h3>

# %%
df_credit.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   character  68029 non-null  object
#  4   role       77801 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ MB

# %%
df_credit.drop('character',axis=1,inplace=True)

# %%
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   role       77801 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.4+ MB

# %%
df_credit.isnull().sum()
# Out:
# person_id    0
# id           0
# name         0
# role         0
# dtype: int64

# %% [markdown]
# <h3>EDA ON Title DataFrame</h3>

# %%
df_title.head()
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1   tm84618                          Taxi Driver  MOVIE          1976
# 2  tm154986                          Deliverance  MOVIE          1972
# 3  tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 4  tm120801                      The Dirty Dozen  MOVIE          1967
#
#    runtime                                       genres production_countries  \
# 0       51                            ['documentation']               ['US']
# 1      114                           ['drama', 'crime']               ['US']
# 2      109  ['drama', 'action', 'thriller', 'european']               ['US']
# 3       91              ['fantasy', 'action', 'comedy']               ['GB']
# 4      150                            ['war', 'action']         ['GB', 'US']
#
#    seasons  imdb_score     imdb_votes  tmdb_popularity  tmdb_score
# ...

# %%
df_title['type'].value_counts()
# Out:
# MOVIE    3743
# SHOW     2106
# Name: type, dtype: int64

# %%
df_title['type'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()

# %%
top_ten_imdb_score_movie=df_title[['title','imdb_score']].sort_values(by="imdb_score",ascending=False)[:10]
top_ten_imdb_score_movie
# Out:
#                            title  imdb_score
# 2658                    #ABtalks         9.6
# 564                     Khawatir         9.5
# 216                 Breaking Bad         9.5
# 3147                  Our Planet         9.3
# 233   Avatar: The Last Airbender         9.3
# 1258                  Reply 1988         9.2
# 3068              The Last Dance         9.1
# 4771                       Major         9.1
# 1886                   My Mister         9.1
# 3500                Kota Factory         9.1

# %%
plt.figure(figsize=(12, 7))
sns.barplot(x="imdb_score", y="title", data=top_ten_imdb_score_movie)
plt.title("Top 10 Netflix Movie/Show")
plt.show()

# %%
plt.plot(top_ten_imdb_score_movie['title'],top_ten_imdb_score_movie['imdb_score'],marker='D')
plt.xticks(rotation='vertical')
plt.show()

# %%
df_title[df_title['imdb_score']==df_title['imdb_score'].max()]
# Out:
#             id     title  type  release_year  runtime genres  \
# 2658  ts265844  #ABtalks  SHOW          2018       68     []
#
#      production_countries  seasons  imdb_score  imdb_votes  tmdb_popularity  \
# 2658                   []      1.0         9.6         7.0        12.288223
#
#       tmdb_score
# 2658    6.733719

# %%
movie_df=df_title[df_title['type']=='MOVIE']
movie_df.head()
# Out:
#          id                            title   type  release_year  runtime  \
# 1   tm84618                      Taxi Driver  MOVIE          1976      114
# 2  tm154986                      Deliverance  MOVIE          1972      109
# 3  tm127384  Monty Python and the Holy Grail  MOVIE          1975       91
# 4  tm120801                  The Dirty Dozen  MOVIE          1967      150
# 6   tm70993                    Life of Brian  MOVIE          1979       94
#
#                                         genres production_countries  seasons  \
# 1                           ['drama', 'crime']               ['US']      1.0
# 2  ['drama', 'action', 'thriller', 'european']               ['US']      1.0
# 3              ['fantasy', 'action', 'comedy']               ['GB']      1.0
# 4                            ['war', 'action']         ['GB', 'US']      1.0
# 6                                   ['comedy']               ['GB']      1.0
#
# ...

# %%
top_five_movie=movie_df[['title','imdb_score','seasons','release_year']].sort_values(by="imdb_score",ascending=False)[:10]
top_five_movie
# Out:
#                                          title  imdb_score  seasons  \
# 4771                                     Major         9.1      1.0
# 1092         Chhota Bheem & Krishna vs Zimbara         9.1      1.0
# 3271  David Attenborough: A Life on Our Planet         8.9      1.0
# 2547                         C/o Kancharapalem         8.9      1.0
# 97                                Forrest Gump         8.8      1.0
# 237                                  Inception         8.8      1.0
# 438                        A Lion in the House         8.7      1.0
# 435                                 Anbe Sivam         8.7      1.0
# 792       Chhota Bheem & Krishna in Mayanagari         8.7      1.0
# 1096                Chhota Bheem Neeli Pahaadi         8.7      1.0
#
#       release_year
# 4771          2022
# 1092          2013
# 3271          2020
# 2547          2018
# 97            1994
# 237           2010
# 438           2006
# 435           2003
# 792           2011
# ...

# %%
plt.barh(top_five_movie['title'],top_five_movie['imdb_score'])
plt.xticks(rotation='vertical')
plt.title('Top 10 Netflix Movie')
plt.xlabel('IMDB Rating')
plt.ylabel('Movie Name')
plt.show()

# %%
show_df=df_title[df_title['type']=='SHOW']
show_df.head()
# Out:
#           id                                title  type  release_year  \
# 0   ts300399  Five Came Back: The Reference Films  SHOW          1945
# 5    ts22164         Monty Python's Flying Circus  SHOW          1969
# 26   ts45948     Monty Python's Fliegender Zirkus  SHOW          1972
# 35   ts20681                             Seinfeld  SHOW          1989
# 44   ts22082                         Knight Rider  SHOW          1982
#
#     runtime                                 genres production_countries  \
# 0        51                      ['documentation']               ['US']
# 5        30                 ['comedy', 'european']               ['GB']
# 26       43                             ['comedy']                   []
# 35       24                             ['comedy']               ['US']
# 44       51  ['scifi', 'action', 'crime', 'drama']               ['US']
#
#     seasons  imdb_score     imdb_votes  tmdb_popularity  tmdb_score
# ...

# %%
top_five_show=show_df[['title','imdb_score','seasons','release_year']].sort_values(by="imdb_score",ascending=False)[:10]
top_five_show
# Out:
#                            title  imdb_score  seasons  release_year
# 2658                    #ABtalks         9.6      1.0          2018
# 216                 Breaking Bad         9.5      5.0          2008
# 564                     Khawatir         9.5     11.0          2005
# 3147                  Our Planet         9.3      1.0          2019
# 233   Avatar: The Last Airbender         9.3      3.0          2005
# 1258                  Reply 1988         9.2      1.0          2015
# 1886                   My Mister         9.1      1.0          2018
# 3068              The Last Dance         9.1      1.0          2020
# 3500                Kota Factory         9.1      2.0          2019
# 835              Attack on Titan         9.0      4.0          2013

# %%
plt.bar(top_five_show['title'],top_five_show['imdb_score'])
plt.xticks(rotation='vertical')
plt.title('Top 10 Netflix Show')
plt.xlabel('Show Name')
plt.ylabel('IMDB Rating')
plt.show()

# %%
df_title.head()
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1   tm84618                          Taxi Driver  MOVIE          1976
# 2  tm154986                          Deliverance  MOVIE          1972
# 3  tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 4  tm120801                      The Dirty Dozen  MOVIE          1967
#
#    runtime                                       genres production_countries  \
# 0       51                            ['documentation']               ['US']
# 1      114                           ['drama', 'crime']               ['US']
# 2      109  ['drama', 'action', 'thriller', 'european']               ['US']
# 3       91              ['fantasy', 'action', 'comedy']               ['GB']
# 4      150                            ['war', 'action']         ['GB', 'US']
#
#    seasons  imdb_score     imdb_votes  tmdb_popularity  tmdb_score
# ...

# %% [markdown]
# <h3>EDA ON Credit DataFrame</h3>

# %%
df_credit.head()
# Out:
#    person_id       id             name   role
# 0       3748  tm84618   Robert De Niro  ACTOR
# 1      14658  tm84618     Jodie Foster  ACTOR
# 2       7064  tm84618    Albert Brooks  ACTOR
# 3       3739  tm84618    Harvey Keitel  ACTOR
# 4      48933  tm84618  Cybill Shepherd  ACTOR

# %%
top_artist=df_credit.groupby("name").count().sort_values(by="id",ascending=False)["id"][:10]
top_artist
# Out:
# name
# Boman Irani              25
# Kareena Kapoor Khan      25
# Shah Rukh Khan           23
# Takahiro Sakurai         21
# Raúl Campos              20
# Paresh Rawal             20
# Amitabh Bachchan         20
# Priyanka Chopra Jonas    20
# Jan Suter                19
# Junichi Suwabe           19
# Name: id, dtype: int64

# %%
top_artist.plot.barh()
plt.show()

# %%
temp=df_credit.groupby(['id','name']).count().sort_values(by="id",ascending=True)
temp
# Out:
#                           person_id  role
# id        name
# tm1000037 Anna Fialová            1     1
#           Victor Boccard          1     1
#           Sara Sandeva            1     1
#           Mélanie Fouché          1     1
#           Milan Peschel           1     1
# ...                             ...   ...
# ts98316   John Hurt               1     1
# ts987     Edward Kelsey           1     1
#           Brian Trueman           1     1
#           David Jason             1     1
#           Terry Scott             1     1
#
# [77370 rows x 2 columns]

# %%
df_title['release_year'].unique()
# Out:
# array([1945, 1976, 1972, 1975, 1967, 1969, 1979, 1971, 1980, 1961, 1966,
#        1954, 1958, 1977, 1963, 1956, 1960, 1973, 1974, 1959, 1978, 1989,
#        1990, 1987, 1984, 1983, 1982, 1986, 1981, 1988, 1985, 2000, 1996,
#        1997, 1995, 1994, 1999, 1998, 1993, 1992, 1991, 2008, 2002, 2010,
#        2005, 2007, 2004, 2006, 2009, 2003, 2001, 2011, 2012, 2013, 2014,
#        2015, 2016, 2018, 2017, 2019, 2020, 2022, 2021], dtype=int64)

# %%
year=[1945, 1976, 1972, 1975, 1967, 1969, 1979, 1971, 1980, 1961, 1966,
       1954, 1958, 1977, 1963, 1956, 1960, 1973, 1974, 1959, 1978, 1989,
       1990, 1987, 1984, 1983, 1982, 1986, 1981, 1988, 1985, 2000, 1996,
       1997, 1995, 1994, 1999, 1998, 1993, 1992, 1991, 2008, 2002, 2010,
       2005, 2007, 2004, 2006, 2009, 2003, 2001, 2011, 2012, 2013, 2014,
       2015, 2016, 2018, 2017, 2019, 2020, 2022, 2021]

for i in year:
    temp=df_title[df_title['release_year']==i]
    top=temp[['title','imdb_score']].sort_values(by="imdb_score",ascending=False)[:5]
    
    plt.figure(figsize=(7, 3))
    sns.barplot(x="imdb_score", y="title", data=top)
    plt.title(f"Based On IMDB Rating Top Netflix  Movie/Show  In Year {i}")
    plt.show()

# %%
year=[1945, 1976, 1972, 1975, 1967, 1969, 1979, 1971, 1980, 1961, 1966,
       1954, 1958, 1977, 1963, 1956, 1960, 1973, 1974, 1959, 1978, 1989,
       1990, 1987, 1984, 1983, 1982, 1986, 1981, 1988, 1985, 2000, 1996,
       1997, 1995, 1994, 1999, 1998, 1993, 1992, 1991, 2008, 2002, 2010,
       2005, 2007, 2004, 2006, 2009, 2003, 2001, 2011, 2012, 2013, 2014,
       2015, 2016, 2018, 2017, 2019, 2020, 2022, 2021]

for i in year:
    temp=df_title[df_title['release_year']==i]
    top=temp[['title','tmdb_score']].sort_values(by="tmdb_score",ascending=False)[:5]
    
    plt.figure(figsize=(7, 3))
    sns.barplot(x="tmdb_score", y="title", data=top)
    plt.title(f"Based On TMDB Rating Top Netflix Movie/Show In Year {i}")
    plt.show()
